# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/FS_qtr.csv', encoding='utf-8', index_col=0)
print(df.shape)
df.head()
# Out:
# (1635, 30)
#    公司代號  公司名稱        營業收入        營業成本  原始認列生物資產及農產品之利益（損失）    營業毛利（毛損）  \
# 0  1101    台泥  57500246.0  41440890.0                  NaN  16059356.0
# 1  1102    亞泥  39009089.0  29679533.0                  NaN   9329556.0
# 2  1103    嘉泥   1000927.0    856092.0                  NaN    144835.0
# 3  1104  環球水泥   2314855.0   2049605.0                  NaN    265250.0
# 4  1108  幸福水泥   1684246.0   1621869.0                  NaN     62377.0
#
#    生物資產當期公允價值減出售成本之變動利益（損失）  未實現銷貨（損）益  已實現銷貨（損）益  營業毛利（毛損）淨額    ...      \
# 0                       NaN        NaN        NaN  16059356.0    ...
# 1                       NaN        0.0      518.0   9330074.0    ...
# 2                       NaN        NaN        NaN    144835.0    ...
# 3                       NaN        NaN        NaN    265250.0    ...
# 4                       NaN        NaN        NaN     62377.0    ...
#
#    其他綜合損益（淨額）  合併前非屬共同控制股權綜合損益淨額  本期綜合損益總額  淨利（淨損）歸屬於母公司業主  \
# 0   6342317.0                NaN  16918622      10009630.0
# 1   4111990.0                NaN  11892925       6226635.0
# 2   1502837.0                NaN   1944483        399116.0
# 3     92573.0                NaN    500971        412775.0
# 4     -5570.0                NaN    -13723         -7022.0
#
#    淨利（淨損）歸屬於共同控制下前手權益  淨利（淨損）歸屬於非控制權益  綜合損益總額歸屬於母公司業主  綜合損益總額歸屬於共同控制下前手權益  \
# 0                 NaN        566675.0      16290317.0                 NaN
# 1                 NaN       1554300.0      10178898.0                 NaN
# 2                 NaN         42530.0       1869002.0                 NaN
# 3                 NaN         -4377.0        505348.0                 NaN
# 4                 NaN         -1131.0        -12592.0                 NaN
#
#    綜合損益總額歸屬於非控制權益  基本每股盈餘（元）
# 0        628305.0       2.14
# 1       1714027.0       1.98
# 2         75481.0       0.62
# 3         -4377.0       0.63
# 4         -1131.0      -0.02
#
# [5 rows x 30 columns]

# %% [markdown]
# #### DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Remove missing values.

# %%
df1 = df.copy()
df1 = df1.dropna(how='any', axis=1)
print(df1.shape)
df1.head()
# Out:
# (1635, 10)
#    公司代號  公司名稱     營業費用  營業利益（損失）  營業外收入及支出  稅前淨利（淨損）  繼續營業單位本期淨利（淨損）  \
# 0  1101    台泥  2429709  13629647    810554  14440201        10576305
# 1  1102    亞泥  1605059   7725015   2114043   9839058         7780935
# 2  1103    嘉泥   166691    -21856    234262    212406          125963
# 3  1104  環球水泥   193684     71566    406175    477741          408398
# 4  1108  幸福水泥   111128    -32695     -1149    -33844           -7975
#
#    本期淨利（淨損）  本期綜合損益總額  基本每股盈餘（元）
# 0  10576305  16918622       2.14
# 1   7780935  11892925       1.98
# 2    441646   1944483       0.62
# 3    408398    500971       0.63
# 4     -8153    -13723      -0.02

# %% [markdown]
# #### DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs)
# Fill NA/NaN values using the specified method

# %%
df1 = df.copy()
df1 = df1.fillna(0)
print(df1.shape)
df1.head()
# Out:
# (1635, 30)
#    公司代號  公司名稱        營業收入        營業成本  原始認列生物資產及農產品之利益（損失）    營業毛利（毛損）  \
# 0  1101    台泥  57500246.0  41440890.0                  0.0  16059356.0
# 1  1102    亞泥  39009089.0  29679533.0                  0.0   9329556.0
# 2  1103    嘉泥   1000927.0    856092.0                  0.0    144835.0
# 3  1104  環球水泥   2314855.0   2049605.0                  0.0    265250.0
# 4  1108  幸福水泥   1684246.0   1621869.0                  0.0     62377.0
#
#    生物資產當期公允價值減出售成本之變動利益（損失）  未實現銷貨（損）益  已實現銷貨（損）益  營業毛利（毛損）淨額    ...      \
# 0                       0.0        0.0        0.0  16059356.0    ...
# 1                       0.0        0.0      518.0   9330074.0    ...
# 2                       0.0        0.0        0.0    144835.0    ...
# 3                       0.0        0.0        0.0    265250.0    ...
# 4                       0.0        0.0        0.0     62377.0    ...
#
#    其他綜合損益（淨額）  合併前非屬共同控制股權綜合損益淨額  本期綜合損益總額  淨利（淨損）歸屬於母公司業主  \
# 0   6342317.0                0.0  16918622      10009630.0
# 1   4111990.0                0.0  11892925       6226635.0
# 2   1502837.0                0.0   1944483        399116.0
# 3     92573.0                0.0    500971        412775.0
# 4     -5570.0                0.0    -13723         -7022.0
#
#    淨利（淨損）歸屬於共同控制下前手權益  淨利（淨損）歸屬於非控制權益  綜合損益總額歸屬於母公司業主  綜合損益總額歸屬於共同控制下前手權益  \
# 0                 0.0        566675.0      16290317.0                 0.0
# 1                 0.0       1554300.0      10178898.0                 0.0
# 2                 0.0         42530.0       1869002.0                 0.0
# 3                 0.0         -4377.0        505348.0                 0.0
# 4                 0.0         -1131.0        -12592.0                 0.0
#
#    綜合損益總額歸屬於非控制權益  基本每股盈餘（元）
# 0        628305.0       2.14
# 1       1714027.0       1.98
# 2         75481.0       0.62
# 3         -4377.0       0.63
# 4         -1131.0      -0.02
#
# [5 rows x 30 columns]

# %%
df1 = df.copy()
df1 = df1.fillna(method='ffill', axis=1)
print(df1.shape)
df1.head()
# Out:
# (1635, 30)
#    公司代號  公司名稱         營業收入         營業成本 原始認列生物資產及農產品之利益（損失）     營業毛利（毛損）  \
# 0  1101    台泥  5.75002e+07  4.14409e+07         4.14409e+07  1.60594e+07
# 1  1102    亞泥  3.90091e+07  2.96795e+07         2.96795e+07  9.32956e+06
# 2  1103    嘉泥  1.00093e+06       856092              856092       144835
# 3  1104  環球水泥  2.31486e+06  2.04960e+06         2.04960e+06       265250
# 4  1108  幸福水泥  1.68425e+06  1.62187e+06         1.62187e+06        62377
#
#   生物資產當期公允價值減出售成本之變動利益（損失）    未實現銷貨（損）益    已實現銷貨（損）益   營業毛利（毛損）淨額    ...     \
# 0              1.60594e+07  1.60594e+07  1.60594e+07  1.60594e+07    ...
# 1              9.32956e+06            0          518  9.33007e+06    ...
# 2                   144835       144835       144835       144835    ...
# 3                   265250       265250       265250       265250    ...
# 4                    62377        62377        62377        62377    ...
#
#     其他綜合損益（淨額） 合併前非屬共同控制股權綜合損益淨額  本期綜合損益總額 淨利（淨損）歸屬於母公司業主 淨利（淨損）歸屬於共同控制下前手權益  \
# 0  6.34232e+06       6.34232e+06  16918622    1.00096e+07        1.00096e+07
# 1  4.11199e+06       4.11199e+06  11892925    6.22664e+06        6.22664e+06
# 2  1.50284e+06       1.50284e+06   1944483         399116             399116
# 3        92573             92573    500971         412775             412775
# 4        -5570             -5570    -13723          -7022              -7022
#
#   淨利（淨損）歸屬於非控制權益 綜合損益總額歸屬於母公司業主 綜合損益總額歸屬於共同控制下前手權益 綜合損益總額歸屬於非控制權益 基本每股盈餘（元）
# 0         566675    1.62903e+07        1.62903e+07         628305      2.14
# 1     1.5543e+06    1.01789e+07        1.01789e+07    1.71403e+06      1.98
# 2          42530      1.869e+06          1.869e+06          75481      0.62
# 3          -4377         505348             505348          -4377      0.63
# 4          -1131         -12592             -12592          -1131     -0.02
#
# [5 rows x 30 columns]

# %% [markdown]
# #### DataFrame.duplicated(subset=None, keep='first')
# Return boolean Series denoting <font color="red">duplicate rows</font>, optionally only considering certain columns
#
# #### DataFrame.drop_duplicates(subset=None, keep='first', inplace=False)
# Return DataFrame with duplicate rows removed, optionally only considering certain columns

# %%
# create a duplicated row
df1.iloc[1] = df1.iloc[0]
df1.head()
# Out:
#    公司代號  公司名稱         營業收入         營業成本 原始認列生物資產及農產品之利益（損失）     營業毛利（毛損）  \
# 0  1101    台泥  5.75002e+07  4.14409e+07         4.14409e+07  1.60594e+07
# 1  1101    台泥  5.75002e+07  4.14409e+07         4.14409e+07  1.60594e+07
# 2  1103    嘉泥  1.00093e+06       856092              856092       144835
# 3  1104  環球水泥  2.31486e+06  2.04960e+06         2.04960e+06       265250
# 4  1108  幸福水泥  1.68425e+06  1.62187e+06         1.62187e+06        62377
#
#   生物資產當期公允價值減出售成本之變動利益（損失）    未實現銷貨（損）益    已實現銷貨（損）益   營業毛利（毛損）淨額    ...     \
# 0              1.60594e+07  1.60594e+07  1.60594e+07  1.60594e+07    ...
# 1              1.60594e+07  1.60594e+07  1.60594e+07  1.60594e+07    ...
# 2                   144835       144835       144835       144835    ...
# 3                   265250       265250       265250       265250    ...
# 4                    62377        62377        62377        62377    ...
#
#     其他綜合損益（淨額） 合併前非屬共同控制股權綜合損益淨額  本期綜合損益總額 淨利（淨損）歸屬於母公司業主 淨利（淨損）歸屬於共同控制下前手權益  \
# 0  6.34232e+06       6.34232e+06  16918622    1.00096e+07        1.00096e+07
# 1  6.34232e+06       6.34232e+06  16918622    1.00096e+07        1.00096e+07
# 2  1.50284e+06       1.50284e+06   1944483         399116             399116
# 3        92573             92573    500971         412775             412775
# 4        -5570             -5570    -13723          -7022              -7022
#
#   淨利（淨損）歸屬於非控制權益 綜合損益總額歸屬於母公司業主 綜合損益總額歸屬於共同控制下前手權益 綜合損益總額歸屬於非控制權益 基本每股盈餘（元）
# 0         566675    1.62903e+07        1.62903e+07         628305      2.14
# 1         566675    1.62903e+07        1.62903e+07         628305      2.14
# 2          42530      1.869e+06          1.869e+06          75481      0.62
# 3          -4377         505348             505348          -4377      0.63
# 4          -1131         -12592             -12592          -1131     -0.02
#
# [5 rows x 30 columns]

# %%
df1.duplicated()[:5]
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# #### DataFrame.drop_duplicates(subset=None, keep='first', inplace=False)
# Return DataFrame with duplicate rows removed, optionally only considering certain columns

# %%
df1 = df1.drop_duplicates()
df1.head()
# Out:
#    公司代號  公司名稱         營業收入         營業成本 原始認列生物資產及農產品之利益（損失）     營業毛利（毛損）  \
# 0  1101    台泥  5.75002e+07  4.14409e+07         4.14409e+07  1.60594e+07
# 2  1103    嘉泥  1.00093e+06       856092              856092       144835
# 3  1104  環球水泥  2.31486e+06  2.04960e+06         2.04960e+06       265250
# 4  1108  幸福水泥  1.68425e+06  1.62187e+06         1.62187e+06        62377
# 5  1109  信大水泥  2.80956e+06  1.98728e+06         1.98728e+06       822279
#
#   生物資產當期公允價值減出售成本之變動利益（損失）    未實現銷貨（損）益    已實現銷貨（損）益   營業毛利（毛損）淨額    ...     \
# 0              1.60594e+07  1.60594e+07  1.60594e+07  1.60594e+07    ...
# 2                   144835       144835       144835       144835    ...
# 3                   265250       265250       265250       265250    ...
# 4                    62377        62377        62377        62377    ...
# 5                   822279       822279       822279       822279    ...
#
#     其他綜合損益（淨額） 合併前非屬共同控制股權綜合損益淨額  本期綜合損益總額 淨利（淨損）歸屬於母公司業主 淨利（淨損）歸屬於共同控制下前手權益  \
# 0  6.34232e+06       6.34232e+06  16918622    1.00096e+07        1.00096e+07
# 2  1.50284e+06       1.50284e+06   1944483         399116             399116
# 3        92573             92573    500971         412775             412775
# 4        -5570             -5570    -13723          -7022              -7022
# 5        15924             15924    408033         248086             248086
#
#   淨利（淨損）歸屬於非控制權益 綜合損益總額歸屬於母公司業主 綜合損益總額歸屬於共同控制下前手權益 綜合損益總額歸屬於非控制權益 基本每股盈餘（元）
# 0         566675    1.62903e+07        1.62903e+07         628305      2.14
# 2          42530      1.869e+06          1.869e+06          75481      0.62
# 3          -4377         505348             505348          -4377      0.63
# 4          -1131         -12592             -12592          -1131     -0.02
# 5         144023         258482             258482         149551      0.69
#
# [5 rows x 30 columns]

# %%
df2 = pd.DataFrame()
df2['公司代號'] = df['公司代號']
df2['公司名稱'] = df['公司名稱']
df2['毛利率(%)'] = round(df['營業毛利（毛損）'] / df['營業收入'] * 100, 2)
df2['營業利益率(%)'] = round(df['營業利益（損失）'] / df['營業收入'] * 100, 2)
df2['業外佔税前淨利比(%)'] = round(df['營業外收入及支出'] / df['稅前淨利（淨損）'] * 100, 2)
df2['稅後淨利率(%)'] = round(df['本期淨利（淨損）'] / df['營業收入'] * 100, 2)
df2['EPS'] = df['基本每股盈餘（元）']
df2 = df2.set_index('公司代號')
df2.head()
# Out:
#       公司名稱  毛利率(%)  營業利益率(%)  業外佔税前淨利比(%)  稅後淨利率(%)   EPS
# 公司代號
# 1101    台泥   27.93     23.70         5.61     18.39  2.14
# 1102    亞泥   23.92     19.80        21.49     19.95  1.98
# 1103    嘉泥   14.47     -2.18       110.29     44.12  0.62
# 1104  環球水泥   11.46      3.09        85.02     17.64  0.63
# 1108  幸福水泥    3.70     -1.94         3.39     -0.48 -0.02

# %%
df2.loc[2451: 2454]
# Out:
#       公司名稱  毛利率(%)  營業利益率(%)  業外佔税前淨利比(%)  稅後淨利率(%)   EPS
# 公司代號
# 2451  創見資訊   20.99     12.81        22.20     13.06  2.79
# 2453    凌群   24.36      1.45        10.27      0.90  0.23
# 2454   聯發科   38.31      5.47        49.27      9.22  6.44

# %%
df = pd.read_csv('data/tips.csv')
df.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
df['time'] = df['time'].str.lower()
df.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  dinner     2
# 1       10.34  1.66     No  Sun  dinner     3
# 2       21.01  3.50     No  Sun  dinner     3
# 3       23.68  3.31     No  Sun  dinner     2
# 4       24.59  3.61     No  Sun  dinner     4

# %% [markdown]
# #### Series.map(arg, na_action=None)
# Map values of <font color='red'>Series</font> using input correspondence (a dict, Series, or function).

# %%
df['smoker'] = df['smoker'].map(lambda x: x.lower())
df.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     no  Sun  dinner     2
# 1       10.34  1.66     no  Sun  dinner     3
# 2       21.01  3.50     no  Sun  dinner     3
# 3       23.68  3.31     no  Sun  dinner     2
# 4       24.59  3.61     no  Sun  dinner     4

# %% [markdown]
# #### DataFrame.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method='pad')
# Replace values given in to_replace with value.

# %%
df.replace('Sun', 'Sunday', inplace=True)
df.replace([2, 3, 4], ['Two', 'Three', 'Four'], inplace=True)
df.replace({'yes': 'YES', 'no': 'NO'}, inplace=True)
df.head()
# Out:
#    total_bill   tip smoker     day    time   size
# 0       16.99  1.01     NO  Sunday  dinner    Two
# 1       10.34  1.66     NO  Sunday  dinner  Three
# 2       21.01   3.5     NO  Sunday  dinner  Three
# 3       23.68  3.31     NO  Sunday  dinner    Two
# 4       24.59  3.61     NO  Sunday  dinner   Four

# %% [markdown]
# #### pandas.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise')
# Bin values into discrete intervals.
#
# #### pandas.qcut(x, q, labels=None, retbins=False, precision=3)
# Quantile-based discretization function.
#
# q : integer or array of quantiles
#
# Number of quantiles. 10 for deciles, 4 for quartiles, etc. Alternately array of quantiles, e.g. [0, .25, .5, .75, 1.] for quartiles
#
# #### Series.value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True)
# Returns object containing counts of unique values.

# %%
df = pd.read_csv('data/tips.csv')
print(df.shape)
df['tip'].min(), df['tip'].max()
# Out:
# (244, 6)
# (1.0, 10.0)

# %%
bins = [0, 2, 4, 6, 8, 10]
tip_bins = pd.cut(df['tip'], bins)
pd.value_counts(tip_bins, sort=False)
# Out:
# (0, 2]      78
# (2, 4]     125
# (4, 6]      34
# (6, 8]       5
# (8, 10]      2
# Name: tip, dtype: int64

# %%
tip_bins = pd.qcut(df['tip'], 4)
pd.value_counts(tip_bins)
# Out:
# (0.999, 2.0]     78
# (3.562, 10.0]    61
# (2.9, 3.562]     61
# (2.0, 2.9]       44
# Name: tip, dtype: int64

# %%
tip_bins = pd.qcut(df['tip'], [0, .33, .67, 1.])
pd.value_counts(tip_bins)
# Out:
# (2.022, 3.266]    82
# (3.266, 10.0]     81
# (0.999, 2.022]    81
# Name: tip, dtype: int64

# %% [markdown]
# DataFrame.plot(x=None, y=None, kind='line', ax=None, subplots=False, sharex=None, sharey=False, layout=None, figsize=None, use_index=True, title=None, grid=None, legend=True, style=None, logx=False, logy=False, loglog=False, xticks=None, yticks=None, xlim=None, ylim=None, rot=None, fontsize=None, colormap=None, table=False, yerr=None, xerr=None, secondary_y=False, sort_columns=False, **kwds)[source]
# Make plots of DataFrame using matplotlib / pylab.

# %%
df['tip'].plot(kind='hist', bins=20, edgecolor='black')

# %% [markdown]
# #### DataFrame.all(axis=0, bool_only=None, skipna=True, level=None, **kwargs)[source]
# Return whether all elements are True, potentially over an axis.

# %%
df[(df >= 5).all(axis=1)]
# Out:
#      total_bill   tip smoker   day    time  size
# 141       34.30  6.70     No  Thur   Lunch     6
# 142       41.19  5.00     No  Thur   Lunch     5
# 143       27.05  5.00     No  Thur   Lunch     6
# 155       29.85  5.14     No   Sun  Dinner     5
# 156       48.17  5.00     No   Sun  Dinner     6
# 185       20.69  5.00     No   Sun  Dinner     5

# %% [markdown]
# #### DataFrame.any(axis=0, bool_only=None, skipna=True, level=None, **kwargs)[source]
# Return whether any element is True over requested axis.

# %%
df[(df[['total_bill', 'tip']] >= 45).any(axis=1)]
# Out:
#      total_bill    tip smoker  day    time  size
# 59        48.27   6.73     No  Sat  Dinner     4
# 156       48.17   5.00     No  Sun  Dinner     6
# 170       50.81  10.00    Yes  Sat  Dinner     3
# 182       45.35   3.50    Yes  Sun  Dinner     3
# 212       48.33   9.00     No  Sat  Dinner     4

# %% [markdown]
# #### pandas.get_dummies(data, prefix=None, prefix_sep='_', dummy_na=False, columns=None, sparse=False, drop_first=False, dtype=None)
# Convert <font color="red">categorical</font> variable into dummy/indicator variables (one-hot encoder)

# %%
# one-hot-encoded table
df1 = df.copy()
dummies = pd.get_dummies(df1['smoker'], prefix='smoker')
df1 = df1.join(dummies)
df1.head()
# Out:
#    total_bill   tip smoker  day    time  size  smoker_No  smoker_Yes
# 0       16.99  1.01     No  Sun  Dinner     2          1           0
# 1       10.34  1.66     No  Sun  Dinner     3          1           0
# 2       21.01  3.50     No  Sun  Dinner     3          1           0
# 3       23.68  3.31     No  Sun  Dinner     2          1           0
# 4       24.59  3.61     No  Sun  Dinner     4          1           0
