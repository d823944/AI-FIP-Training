# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### pandas.read_csv(filepath_or_buffer, sep=', ', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# Read CSV (comma-separated) file into DataFrame

# %%
tips = pd.read_csv('data/tips.csv')
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
tips['tip%'] = round(tips['tip'] / tips['total_bill'] * 100, 1)
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size  tip%
# 0       16.99  1.01     No  Sun  Dinner     2   5.9
# 1       10.34  1.66     No  Sun  Dinner     3  16.1
# 2       21.01  3.50     No  Sun  Dinner     3  16.7
# 3       23.68  3.31     No  Sun  Dinner     2  14.0
# 4       24.59  3.61     No  Sun  Dinner     4  14.7

# %% [markdown]
# #### DataFrame.to_csv(path_or_buf=None, sep=', ', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, mode='w', encoding=None, compression=None, quoting=None, quotechar='"', line_terminator='\n', chunksize=None, tupleize_cols=None, date_format=None, doublequote=True, escapechar=None, decimal='.')
# Write DataFrame to a comma-separated values (csv) file

# %%
tips.to_csv('data/tips_new.csv')

# %%
tips2 = tips.sort_values(by=['tip%'], ascending=False)
tips2.head()
# Out:
#      total_bill   tip smoker  day    time  size  tip%
# 172        7.25  5.15    Yes  Sun  Dinner     2  71.0
# 178        9.60  4.00    Yes  Sun  Dinner     2  41.7
# 67         3.07  1.00    Yes  Sat  Dinner     1  32.6
# 232       11.61  3.39     No  Sat  Dinner     2  29.2
# 183       23.17  6.50    Yes  Sun  Dinner     4  28.1

# %%
tips2 = tips2.reset_index(drop=True)
tips2.head()
# Out:
#    total_bill   tip smoker  day    time  size  tip%
# 0        7.25  5.15    Yes  Sun  Dinner     2  71.0
# 1        9.60  4.00    Yes  Sun  Dinner     2  41.7
# 2        3.07  1.00    Yes  Sat  Dinner     1  32.6
# 3       11.61  3.39     No  Sat  Dinner     2  29.2
# 4       23.17  6.50    Yes  Sun  Dinner     4  28.1

# %%
tips[tips['size'] == 6]
# Out:
#      total_bill  tip smoker   day    time  size  tip%
# 125       29.80  4.2     No  Thur   Lunch     6  14.1
# 141       34.30  6.7     No  Thur   Lunch     6  19.5
# 143       27.05  5.0     No  Thur   Lunch     6  18.5
# 156       48.17  5.0     No   Sun  Dinner     6  10.4

# %%
print(tips[tips['size'] == 6].shape)
print(tips[tips['size'] == 6].shape[0])
# Out:
# (4, 7)
# 4

# %%
for ppl in range(1, 7):
    print(f'Avg. tip from a table for {ppl} people = ${tips[tips["size"] == ppl]["total_bill"].mean():.2f}')
# Out:
# Avg. tip from a table for 1 people = $7.24
# Avg. tip from a table for 2 people = $16.45
# Avg. tip from a table for 3 people = $23.28
# Avg. tip from a table for 4 people = $28.61
# Avg. tip from a table for 5 people = $30.07
# Avg. tip from a table for 6 people = $34.83

# %%
print(f'Minimum tip% in total bill: {tips["tip%"].min()}%')
print(f'Maximum tip% in total bill: {tips["tip%"].max()}%')
# Out:
# Minimum tip% in total bill: 3.6%
# Maximum tip% in total bill: 71.0%

# %% [markdown]
# #### pandas.read_html(io, match='.+', flavor=None, header=None, index_col=None, skiprows=None, attrs=None, parse_dates=False, tupleize_cols=None, thousands=', ', encoding=None, decimal='.', converters=None, na_values=None, keep_default_na=True, displayed_only=True)
# Read HTML tables into a list of DataFrame objects.

# %%
url = 'https://en.wikichip.org/wiki/mediatek/helio'

tables = pd.read_html(url)
print(f'Number of tables on the webpage: {len(tables)}')
tables[3].head()
# Out:
# Number of tables on the webpage: 6
#             0                                 1                        2   \
# 0          NaN  List of Helio X-based Processors                      NaN
# 1          NaN                    Main processor               Max Memory
# 2        Model                          Launched                  Process
# 3    Helio X10                     27 March 2015  28 nm0.028 μm 2.8e-5 mm
# 4  Helio X10 M                     27 March 2015  28 nm0.028 μm 2.8e-5 mm
#
#       3           4      5                             6   \
# 0    NaN         NaN    NaN                           NaN
# 1    GPU         NaN    NaN                           NaN
# 2    ISA       Cores  Cores                     Frequency
# 3  ARMv8  Cortex-A53      8  2 GHz2,000 MHz 2,000,000 kHz
# 4  ARMv8  Cortex-A53      8  2 GHz2,000 MHz 2,000,000 kHz
#
#                                                   7            8   \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                            Max Mem     Mem Type
# 3  4 GiB4,096 MiB 4,194,304 KiB 4,294,967,296 B 0...  LPDDR3-1866
# 4  4 GiB4,096 MiB 4,194,304 KiB 4,294,967,296 B 0...  LPDDR3-1866
#
#                          9              10                           11
# 0                       NaN            NaN                          NaN
# 1                       NaN            NaN                          NaN
# 2                  Designer           Name                    Frequency
# 3  Imagination Technologies  PowerVR G6200   700 MHz0.7 GHz 700,000 KHz
# 4  Imagination Technologies  PowerVR G6200  550 MHz0.55 GHz 550,000 KHz

# %%
table = tables[3].copy()
table.columns = [
    'Model',
    'Launched',
    'Process',
    'ISA',
    'Cores',
    'Cores',
    'CPU_Freq',
    'Max Mem',
    'Mem Type',
    'Designer',
    'Name',
    'GPU_Freq']

table.drop([0, 1, 2, 12], axis=0, inplace=True)
table.reset_index(drop=True, inplace=True)

table['Process'] = table['Process'].apply(lambda x: str(x).split('nm')[0] + 'nm')
table['CPU_Freq'] = table['CPU_Freq'].apply(lambda x: str(x).split('GHz')[0] + 'GHz')
table['Max Mem'] = table['Max Mem'].apply(lambda x: str(x).split('GiB')[0] + 'GB')
table['GPU_Freq'] = table['GPU_Freq'].apply(lambda x: str(x).split('MHz')[0] + 'MHz')

table
# Out:
#          Model          Launched Process    ISA  \
# 0    Helio X10     27 March 2015   28 nm  ARMv8
# 1  Helio X10 M     27 March 2015   28 nm  ARMv8
# 2  Helio X10 T     27 March 2015   28 nm  ARMv8
# 3  Helio X20 M     16 March 2016   20 nm  ARMv8
# 4    Helio X23   2 December 2016   20 nm  ARMv8
# 5    Helio X25     16 March 2016   20 nm  ARMv8
# 6    Helio X27   2 December 2016   20 nm  ARMv8
# 7    Helio X30  27 February 2017   10 nm  ARMv8
# 8    Helio X20     16 March 2016   20 nm  ARMv8
#
#                                 Cores Cores  CPU_Freq Max Mem      Mem Type  \
# 0                          Cortex-A53     8     2 GHz    4 GB   LPDDR3-1866
# 1                          Cortex-A53     8     2 GHz    4 GB   LPDDR3-1866
# 2                          Cortex-A53     8   2.2 GHz    4 GB   LPDDR3-1866
# 3              Cortex-A53, Cortex-A72    10     2 GHz    6 GB   LPDDR3-1866
# 4              Cortex-A53, Cortex-A72    10   2.3 GHz    4 GB   LPDDR3-1600
# 5              Cortex-A53, Cortex-A72    10   2.5 GHz    6 GB   LPDDR3-1600
# 6              Cortex-A53, Cortex-A72    10   2.6 GHz   nanGB   LPDDR3-1600
# 7  Cortex-A35, Cortex-A53, Cortex-A73    10   2.5 GHz    8 GB  LPDDR4X-3732
# 8              Cortex-A53, Cortex-A72    10  1.85 GHz   nanGB   LPDDR3-1600
#
#                    Designer                 Name GPU_Freq
# 0  Imagination Technologies        PowerVR G6200  700 MHz
# 1  Imagination Technologies        PowerVR G6200  550 MHz
# 2  Imagination Technologies        PowerVR G6200  700 MHz
# 3              ARM Holdings            Mali-T880  780 MHz
# 4              ARM Holdings            Mali-T880  780 MHz
# 5              ARM Holdings            Mali-T880  850 MHz
# 6              ARM Holdings            Mali-T880  875 MHz
# 7  Imagination Technologies  PowerVR GT7400 Plus  800 MHz
# 8              ARM Holdings            Mali-T880  780 MHz

# %% [markdown]
# #### DataFrame.to_excel(excel_writer, sheet_name='Sheet1', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, startrow=0, startcol=0, engine=None, merge_cells=True, encoding=None, inf_rep='inf', verbose=True, freeze_panes=None)
# Write DataFrame to an excel sheet

# %%
excel_writer = pd.ExcelWriter('data/Helio.xlsx')
table.to_excel(excel_writer, 'Helio-X')

# %% [markdown]
# #### pandas.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, **kwds)
# Read an Excel table into a pandas DataFrame

# %%
xlsx = pd.ExcelFile('data/Helio.xlsx')
df = pd.read_excel(xlsx, sheet_name='Helio-X', header=0, index_col=0)
df.set_index('Model', inplace=True)
df.tail()
# Out:
#                      Launched Process    ISA  \
# Model
# Helio X20 M     16 March 2016   20 nm  ARMv8
# Helio X23     2 December 2016   20 nm  ARMv8
# Helio X25       16 March 2016   20 nm  ARMv8
# Helio X27     2 December 2016   20 nm  ARMv8
# Helio X30    27 February 2017   10 nm  ARMv8
#
#                                           Cores  Cores.1 CPU_Freq Max Mem  \
# Model
# Helio X20 M              Cortex-A53, Cortex-A72       10    2 GHz    6 GB
# Helio X23                Cortex-A53, Cortex-A72       10  2.3 GHz    4 GB
# Helio X25                Cortex-A53, Cortex-A72       10  2.5 GHz    6 GB
# Helio X27                Cortex-A53, Cortex-A72       10  2.6 GHz   nanGB
# Helio X30    Cortex-A35, Cortex-A53, Cortex-A73       10  2.5 GHz    8 GB
#
#                  Mem Type                  Designer                 Name  \
# Model
# Helio X20 M   LPDDR3-1866              ARM Holdings            Mali-T880
# Helio X23     LPDDR3-1600              ARM Holdings            Mali-T880
# Helio X25     LPDDR3-1600              ARM Holdings            Mali-T880
# Helio X27     LPDDR3-1600              ARM Holdings            Mali-T880
# Helio X30    LPDDR4X-3732  Imagination Technologies  PowerVR GT7400 Plus
#
#             GPU_Freq
# Model
# Helio X20 M  780 MHz
# Helio X23    780 MHz
# Helio X25    850 MHz
# Helio X27    875 MHz
# Helio X30    800 MHz

# %%
print(df.loc['Helio X30']['Process'])
print(df.loc['Helio X30']['Launched'])
# Out:
# 10 nm
# 27 February 2017

# %%
def month2num(x):
    day, month, year = x.split(' ')
    months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'Octobor', 'November', 'December']
    return '/'.join([str(months.index(month)+1), day, year])
    
df['Launched'] = df['Launched'].apply(month2num)
df
# Out:
#               Launched Process    ISA                               Cores  \
# Model
# Helio X10    3/27/2015   28 nm  ARMv8                          Cortex-A53
# Helio X10 M  3/27/2015   28 nm  ARMv8                          Cortex-A53
# Helio X10 T  3/27/2015   28 nm  ARMv8                          Cortex-A53
# Helio X20    3/16/2016   20 nm  ARMv8              Cortex-A53, Cortex-A72
# Helio X20 M  3/16/2016   20 nm  ARMv8              Cortex-A53, Cortex-A72
# Helio X23    12/2/2016   20 nm  ARMv8              Cortex-A53, Cortex-A72
# Helio X25    3/16/2016   20 nm  ARMv8              Cortex-A53, Cortex-A72
# Helio X27    12/2/2016   20 nm  ARMv8              Cortex-A53, Cortex-A72
# Helio X30    2/27/2017   10 nm  ARMv8  Cortex-A35, Cortex-A53, Cortex-A73
#
#              Cores.1  CPU_Freq Max Mem      Mem Type  \
# Model
# Helio X10          8     2 GHz    4 GB   LPDDR3-1866
# Helio X10 M        8     2 GHz    4 GB   LPDDR3-1866
# Helio X10 T        8   2.2 GHz    4 GB   LPDDR3-1866
# Helio X20         10  1.85 GHz   nanGB   LPDDR3-1600
# Helio X20 M       10     2 GHz    6 GB   LPDDR3-1866
# Helio X23         10   2.3 GHz    4 GB   LPDDR3-1600
# Helio X25         10   2.5 GHz    6 GB   LPDDR3-1600
# Helio X27         10   2.6 GHz   nanGB   LPDDR3-1600
# Helio X30         10   2.5 GHz    8 GB  LPDDR4X-3732
#
#                              Designer                 Name GPU_Freq
# Model
# Helio X10    Imagination Technologies        PowerVR G6200  700 MHz
# Helio X10 M  Imagination Technologies        PowerVR G6200  550 MHz
# Helio X10 T  Imagination Technologies        PowerVR G6200  700 MHz
# Helio X20                ARM Holdings            Mali-T880  780 MHz
# Helio X20 M              ARM Holdings            Mali-T880  780 MHz
# Helio X23                ARM Holdings            Mali-T880  780 MHz
# Helio X25                ARM Holdings            Mali-T880  850 MHz
# Helio X27                ARM Holdings            Mali-T880  875 MHz
# Helio X30    Imagination Technologies  PowerVR GT7400 Plus  800 MHz
