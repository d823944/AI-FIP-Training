# %%
f = lambda x, y: (x, y, x+y)
f(2, 3)
# Out:
# (2, 3, 5)

# %%
sorted([1, 2, 3, 4, 5, 6, 7, 8, 9], key=lambda x: abs(5-x)**2)
# Out:
# [5, 4, 6, 3, 7, 2, 8, 1, 9]

# %%
X = [i for i in range(1, 10)]
Y = [abs(5-x)**2 for x in X]

# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(X, Y)
